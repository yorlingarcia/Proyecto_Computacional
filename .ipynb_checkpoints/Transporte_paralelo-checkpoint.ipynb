# %% [markdown]
# $\textbf{Transporte paralelo}$

# %% [markdown]
# $$\frac{D}{d  \lambda}T_{\nu_1, \nu_2, ..., \nu_l}^{~~~~~~~~~~~~~~~\mu_1, \mu_2, ..., \mu_k} = 0$$
# $$\frac{D}{d  \lambda} = \frac{dx^{\mu}}{d \lambda} \nabla_{\mu}$$
#
# referencia ------ https://www.preposterousuniverse.com/grnotes/
#
# Definiendo un tensor $V^{\mu}$, su transporte paralelo esta dado por
#
# $$\frac{D}{d  \lambda}V^{\mu} = \frac{dx^{\sigma}}{d \lambda} \nabla_{\sigma}V^{\mu} = \frac{dx^{\sigma}}{d \lambda} \partial_{\sigma}V^{\mu} + \Gamma_{\sigma\rho}^{\mu} \frac{dx^{\sigma}}{d \lambda}V^{\rho}= 0$$
#
# $$ \frac{d}{d \lambda}V^{\mu} + \Gamma_{\sigma\rho}^{\mu} \frac{dx^{\sigma}}{d \lambda}V^{\rho}= 0$$
#
# Suponiendo una conexión levi-civita, la conexión toma la forma
#
# $$ \Gamma_{\mu \nu}^{\rho} = \frac{1}{2}g^{\rho \sigma}\left(\partial_{\mu}g_{\nu\sigma} + \partial_{\nu}g_{\mu\sigma} - \partial_{\sigma}g_{\mu\nu}\right)$$
#
# si $V = e_z$, un vector que apunta en la direccion z, ademas tomando la metrica euclidiana (no evolucion temporal) $\eta_{\mu \nu}$, los valores correspondientes a la conexión es

# %%
###########################################
###########################################
import numpy as np
import sympy as sp
from math import sin
from IPython.display import Latex, display
###########################################
###########################################

print('--------metrica euclidiana----------')
D = 2
# r, theta variables simbolicas
metrica = sp.Matrix([['1' , '0' , '0'],['0', '1', '0'],['0', '0', '1']])
print(metrica)
print('-------------------------')

metricainv = metrica.inv()
gamma = np.zeros((D+1,D+1,D+1),list) # simbolos de christoffel
x = ['t','r','theta','phi']

sum = 0
for i in range(D+1): #lambda
    for j in range(D+1): # mu
        for k in range(D+1): # nu
            for l in range(D+1): # sigma
                sum += 0.5*metricainv[i,l]*(sp.diff(metrica[k,l],x[j]) 
                                            + sp.diff(metrica[j,l],x[k]) - sp.diff(metrica[j,k],x[l]))
            gamma[i][j][k] = sum
            sum = 0
aux = 0 # variable suma
for i in range(D+1):
    for j in range(D+1):
        for k in range(D+1): 
            if gamma[i,j,k] != 0: 
                print("gamma(",x[i], x[j], x[k],") = ",gamma[i,j,k])
            else:
                aux += 1
if aux == (D+1)**3:
    print(" los valres de los coeficientes son cero")
# Out:
# --------metrica euclidiana----------
# Matrix([[1, 0, 0], [0, 1, 0], [0, 0, 1]])
# -------------------------
#  los valres de los coeficientes son cero

# %% [markdown]
# Parametrizando una curva (circulo) en el spacio plano
#
# $$ x = cos(\lambda), ~ y = sin(\lambda)$$
# $$\frac{d}{d \lambda} V^{\mu} = 0$$
#
# Esto implica que el vector se mantiene constante bajo el transporte paralelo en el espacio plano

# %%
from pylab import *
from numpy import *
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D, get_test_data
from matplotlib import *

# Figura
fig = plt.figure()

# Tomo el eje actual y defino una proyección 3D
ax = gca(projection='3d')

# Dibujo 3D
X = np.arange(-1.5, 1.5, 0.25)
Y = np.arange(-1.5, 1.5, 0.25)

# el metodo meshgrid devuelve una matriz de coordenadas
# a partir de vectores de coordendas, que usamos para
# los datos del eje Z
X, Y = np.meshgrid(X, Y)

R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)*0

# Grafico surface en 3D
surface = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm, linewidth=0, antialiased=False)

# Límites del eje Z
ax.set_zlim(-1.01, 1.01)
fig.set_size_inches(12,5)

# %%
#ejemplo de grafica de un vector
import matplotlib.pylab as plt
x = [1,0]
y = [0,1]
plt.quiver(x[1], y[0], x[0], y[1],scale_units = 'xy',angles='xy', scale=1)
plt.grid(True)
plt.xlim(-1,2)
plt.ylim(-1,2)
# Out:
# (-1, 2)

# %%
np.matmul(np.array([2,2]),np.array([[2],[1]]))
# Out:
# array([6])

# %%
V = np.array([1,0])
x = np.array([[1],[0]])*V[0]
y = np.array([[0],[1]])*V[1]
plt.quiver(x[1], y[0], x[0], y[1],scale_units = 'xy',angles='xy', scale=1)
plt.grid(True)
plt.xlim(-1,2)
plt.ylim(-1,2)
# Out:
# (-1, 2)

# %%
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')


Vini = np.array([1,1,0])
Vfin = np.array([0,0,2])

ax.quiver(Vini[0],Vini[1],Vini[2],Vfin[0],Vfin[1],Vfin[2],length=2, normalize=True)
ax.view_init(elev=10, azim=45)
ax.set_xlim(-2,2)
ax.set_ylim(-2,2)
ax.set_zlim(-2,2)
# Out:
# (-2, 2)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

#x = np.array([[1],[0],[0]])*V[0]
#y = np.array([[0],[1],[1]])*V[1]
#z = np.array([[0],[0],[1]])*V[2]
for i in arange(0,2*np.pi,np.pi/20):
    Vini = np.array([cos(i),sin(i),0])
    Vfin = np.array([0,0,1])
    ax.quiver(Vini[0],Vini[1],Vini[2],Vfin[0],Vfin[1],Vfin[2],length=1, normalize=True)
    ax.view_init(elev=45, azim=90)
    ax.set_xlim(-1,1)
    ax.set_ylim(-1,1)
    ax.set_zlim(0,1)

# %%
# animación del transporte(falta quitar el solapamiento)
from IPython import display
fig = plt.figure()
ax = fig.gca(projection='3d')

for i in arange(0,2*np.pi,np.pi/20):
    Vini = np.array([cos(i),sin(i),0])
    Vfin = np.array([0,0,1])
    #ax.view_init(elev=45, azim=90)
    plt.gca().cla()
    #fig.set_size_inches(12,5)
    ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.cool, linewidth=0, antialiased=False)
    ax.quiver(Vini[0],Vini[1],Vini[2],Vfin[0],Vfin[1],Vfin[2],length=1, normalize=True)
    ax.set_zlim(0,1)
    display.clear_output(wait=True)
    display.display(plt.gcf())
#ax.set_xlim(-1,1)
#ax.set_ylim(-1,1)
#ax.set_zlim(0,1)

# %% [markdown]
# para cualquier vector del espacio plano, sigue la consecuencia de que su trasporte paralelo no modifica su dirección, podemos colocar un ejemplo mas para definir el fenomeno del transporte
#
# $$ V = xe_x +ye_y $$

# %% [markdown]
# tomando la curva $x(\lambda)$, como un circulo sobre la superficie

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
theta = arange(0,np.pi*2,np.pi/20)
x = np.cos(theta)
y = np.sin(theta)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.cool, linewidth=0, antialiased=False)
ax.plot(x,y,0,'b',linewidth = 10)
ax.set_zlim(-0.5,1)
ax.view_init(elev=0, azim=90)
